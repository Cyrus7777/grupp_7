# %% [markdown]
# ---
# # Assignment: Data Visualization using a Visualization Library
# ---
#
# #### In this assignment, you will conduct an exploratory data analysis with visualizations on an Olympic Athletes dataset.
#
# How to use this Notebook:
# -  Firstly, make sure you have completed [1. Setup](#1-setup).
# -  Secondly, complete [Task 1: Preprocessing](#task-1-preprocessing).
# -  Then, you can complete [Task 2: Summary Statistics](#task-2-summary-statistics) to [Task 6: Map Visualizations](#task-6-map-visualizations) in any order.
# -  Lastly, complete [Task 7: Submission](#task-7-submission).
#
# The various tasks contain Notebook cells with `TODO`s.
# - You need to complete all `TODO`s.
#
# Assignment files and folders.
# - The file `assignment.ipynb` is this Notebook.
# - The folder `data` contains:
#   - 4 `.csv` files with the data for this assignment.
#   - A `verify.pkl` file you can use to verify your solution in [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering).
# - The folder `figures` contains:
#   - 19 `.png` figures you can use to verify your solutions to the visualization tasks in [Task 3: Distribution Visualizations](#task-3-distribution-visualizations) to [Task 6: Map Visualizations](#task-6-map-visualizations).
#   - Your visualizations need to be similar, but not identical to, the sample visualizations.
#   - The sample visualizations are provided as an aid so that you know what to aim for.
#
# This Notebook contains:
#
# - [1. Setup](#1-setup)
#   - [Python Virtual Environment](#python-virtual-environment)
#   - [Python and Pip Version](#python-and-pip-version)
#   - [Python Packages](#python-packages)
#   - [Python Modules](#python-modules)
#   - [Pandas Configuration](#pandas-configuration)
#   - [Dataset](#dataset)
# - [Task 1: Preprocessing](#task-1-preprocessing)
#   - [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)
#   - [Task 1.2 Feature Measurement Scales](#task-12-feature-measurement-scales)
# - [Task 2: Summary Statistics](#task-2-summary-statistics)
#   - [Task 2.1 Missing Values](#task-21-missing-values)
#   - [Task 2.2 Unique Values](#task-22-unique-values)
#   - [Task 2.3 Value Counts](#task-23-value-counts)
#   - [Task 2.4 Central Tendency and Spread](#task-24-central-tendency-and-spread)
#   - [Task 2.5 Outliers](#task-25-outliers)
# - [Task 3: Distribution Visualizations](#task-3-distribution-visualizations)
#   - [Task 3.1 Visualize the Distribution of Male and Female Athletes](#task-31-visualize-the-distribution-of-male-and-female-athletes)
#   - [Task 3.2 Visualize the Distribution of Athletes' Age](#task-32-visualize-the-distribution-of-athletes-age)
#   - [Task 3.3 Visualize the Distribution of Athletes' Height](#task-33-visualize-the-distribution-of-athletes-height)
#   - [Task 3.4 Visualize the Distribution of Athletes' Weight](#task-34-visualize-the-distribution-of-athletes-weight)
#   - [Task 3.5 Visualize the Distribution in Height of Male and Female Athletes](#task-35-visualize-the-distribution-in-height-of-male-and-female-athletes)
#   - [Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes](#task-36-visualize-the-height-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes](#task-37-visualize-the-weight-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season](#task-38-visualize-height-per-type-of-medal-for-male-and-female-athletes-faceted-by-season)
#   - [Task 3.9 Visualize the Average Age per Sport](#task-39-visualize-the-average-age-per-sport)
#   - [Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals](#task-310-visualize-the-top-10-countries-regions-with-most-total-medals)
#   - [Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals](#task-311-visualize-the-top-10-atheletes-by-total-awarded-medals)
#   - [Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal](#task-312-visualize-the-age-height-and-weight-distribution-per-type-of-medal)
#   - [Task 3.13 Interpret a Box Plot's Visual Elements](#task-313-interpret-a-box-plots-visual-elements)
# - [Task 4: Trend Visualizations](#task-4-trend-visualizations)
#   - [Task 4.1 Visualize Body Mass Index (BMI) Over Time](#task-41-visualize-body-mass-index-bmi-over-time)
#   - [Task 4.2 Visualize Gender (Sex) Participation Over Time](#task-42-visualize-gender-sex-participation-over-time)
# - [Task 5: Correlation Visualizations](#task-5-correlation-visualizations)
#   - [Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`](#task-51-visualize-pairwise-correlations-of-athletes-age-height-and-weight-per-sex-with-a-pairplot)
#   - [Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`](#task-52-visualize-pairwise-correlations-of-the-numeric-features-with-a-heatmap)
#   - [Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`](#task-53-visualize-atheltes-weight-versus-height-per-sex-with-a-lineplot)
#   - [Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`](#task-54-visualize-atheltes-weight-versus-height-per-sex-with-a-scatterplot)
# - [Task 6: Map Visualizations](#task-6-map-visualizations)
#   - [Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries](#task-61-visualize-number-of-medals-on-a-map-for-the-nordic-countries)
# - [Task 7: Submission](#task-7-submission)
#   - [Task 7.1 Verify the Integrity of your Notebook](#task-71-verify-the-integrity-of-your-notebook)
#   - [Task 7.2 Submit the Assignment](#task-72-submit-the-assignment)

# %% [markdown]
# ---
# # Setup
# ---

# %% [markdown]
# ## Python Virtual Environment
#
# - Make sure you have downloaded the GitHub repository (which contains the assignment).
#   - **Alternative 1**: You can use the same `git clone` as in the workshops.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz
#     cd dataviz
#     ```
#
#   - **Alternative 2**: You can `git clone` the repository into another folder just for the assignment.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz_assignment
#     cd dataviz_assignment
#     ```
#
# - Make sure you have created a Python Virtual Environment as below.
#
#     ```bash
#     conda create -y -p ./.conda python=3.12
#     conda activate ./.conda
#     python -m pip install --upgrade pip
#     pip install ipykernel jupyter pylance numpy pandas matplotlib seaborn basemap pillow
#     # You can install more packages, but for this assignment you need (at least) the packages listed above
#     ```
#
# - Also make sure you have selected your Python Virtual Environment in your Notebook.
#   - In the top right of your Notebook, click `Select Kernel`.
#   - Choose your Python Virtual Environment.

# %% [markdown]
# ---
# ## Python and Pip Version
#
# Let's start by printing out the Python and Pip version you are using in your Python Virtual Environment.

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.11
# pip 25.2 from /home/patrick/projects/dataviz/.conda/lib/python3.12/site-packages/pip (python 3.12)

# %% [markdown]
# ---
# ## Python Packages
#
# Let's also make sure the necessary Python packages are installed in our Python Virtual Environment.
# - I have included some default packages below (many of which might already be installed in your Python Virtual Environment).
# - If you use any other `pip` or `conda` packages, add them in the cell below.
#   - Use `%pip install <package>` for Pip packages.
#   - Use `%conda install <package>` for Conda packages.
#
#
# Note
# - When you install a `conda` package, you might have to restart your Jupyter Notebook kernel.
# - To restart your Jupyter Notebook kernel, click the `Restart` button at the top of the Notebook.

# %%
# %pip install ipykernel
# %pip install jupyter
# %pip install pylance
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install basemap
# %pip install pillow

# %% [markdown]
# ---
# ## Python Modules
#
# Let's import the necessary Python modules from the installed Python packages.
# - Numpy and Pandas are used for data mangling.
# - Matplotlib and/or Seaborn are used for visualizations.
# - If you need more imports, add them in the cell below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ---
# ## Pandas Configuration
#
# Let's also configure Pandas to set the maximum number of rows and columns displayed from a `DataFrame` in a Jupyter Notebook cell.
# - Configuring the maximum number of rows.
#   - `pd.set_option('display.max_rows', None)` displays an unlimited number of rows (don't use this when working with large `DataFrame`s).
#   - `pd.set_option('display.max_rows', 25)` displays a maximum of `25` rows.
#   - `pd.reset_option('display.max_rows')` resets the number of rows to the default setting.
# - Configuring the maximum number of columns.
#   - `pd.set_option('display.max_columns', None)` displays an unlimited number of columns.
#   - `pd.set_option('display.max_columns', 25)` displays a maximum of `25` columns.
#   - `pd.reset_option('display.max_columns')` resets the number of columns to the default setting.

# %%
pd.reset_option('display.max_rows')        # show default number of rows
pd.set_option('display.max_columns', None) # show all columns

# %% [markdown]
# ---
# ## Dataset
#
# Let's load a pre-processed dataset containing information about Olymic athletes, events they competed in, etc., and inspect the features (columns).
# - `ID` is a unique identifier for an athlete.
# - `Name` is the athlete's name.
# - `Sex` is the athlete's sex, `M` for Male, or `F` for female.
# - `Age` is the athlete's age, for a specific `Year`.
# - `Height` is the athlete's height in centimeters (cm).
# - `Weight` is the athlete's weight in kilograms (kg).
# - `BMI` is the athlete's Body Mass Index, calculated as the weight (in kilograms) divided by the height (in meters): $BMI = \frac{Weight[kg]}{Height[m]^2}$
# - `Team` is the Olympic team the athlete is a member of.
# - `NOC` is the National Olympic Committee country code for the athlete.
# - `Region` is the region associated with the athlete's `NOC`.
# - `ISO3` is the ISO 3166-1 alpha-3 country code (a 3-letter code) for the athlete's country.
# - `Country` is the country name associated with the `ISO3` country code.
# - `Latitude` is the country's geographic latitude.
# - `Longitude` is the country's geographic longitude.
# - `Games` is the name of the Olymic games, e.g. `1992 Summer` for the 1992 summer games.
# - `Year` is the year of the Olymipc games.
# - `Season` is the season for the Olymipc games, i.e. `Summer` or `Winter`.
# - `City` is the city in which the Olymic games were held.
# - `Sport` is Olympic sport the athlete competed in.
# - `Event` is Olympic event the athlete competed in.
# - `Medal` is medal (Gold, Silver, Bronze) awarded to the athlete, if any.

# %%
df_verify = pd.read_pickle('data/verify.pkl')
print(f'Number of rows: {df_verify.shape[0]}')
print(f'Number of columns: {df_verify.shape[1]}')
df_verify.head() # head() displays the first 5 rows, head(10) displays the first 10 rows, etc.
# Out:
# Number of rows: 269731
# Number of columns: 21
#    ID                      Name Sex   Age  Height  Weight        BMI  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  24.691358
# 1   2                  A Lamusi   M  23.0   170.0    60.0  20.761246
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        NaN
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN        NaN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  23.959094
#
#              Team  NOC       Region ISO3      Country  Latitude  Longitude  \
# 0           China  CHN        China  CHN        China      35.0     105.00
# 1           China  CHN        China  CHN        China      35.0     105.00
# 2         Denmark  DEN      Denmark  DNK      Denmark      56.0      10.00
# 3  Denmark/Sweden  DEN      Denmark  DNK      Denmark      56.0      10.00
# 4     Netherlands  NED  Netherlands  NLD  Netherlands      52.5       5.75
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# Let's also print out the data types for the various features (columns).

# %%
df_verify.dtypes
# Out:
# ID             int64
# Name          object
# Sex           object
# Age          float64
# Height       float64
# Weight       float64
# BMI          float64
# Team          object
# NOC           object
# Region        object
# ISO3          object
# Country       object
# Latitude     float64
# Longitude    float64
# Games         object
# Year           int64
# Season        object
# City          object
# Sport         object
# Event         object
# Medal         object
# dtype: object

# %% [markdown]
# ---
# # Task 1: Preprocessing
# ---
#
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering
#
# Your first task is to load and preprocess the four `.csv` files in the `data` folder.
# - `athlete_events.csv` contains data about the athletes and events they competed in.
# - `geo.csv` contains ISO3 country codes with latitudes and longitides.
# - `noc_iso3.csv` contains mappings between NOC and ISO3 country codes.
# - `noc_regions.csv` contains NOC country codes with regions.
#
# When you are done, you should end up with **one** Pandas `DataFrame` (`df`) identical to the Pandas `DataFrame` (`df_verify`) above.
# - It should contain:
#   - The exact same column names (including large/small letters), in the same left-to-right order, and with the same data types.
#   - The same number of rows.
# - Once you have created your own DataFrame `df`, you can verify it by comparing it to the `df_verify` DataFrame (see cell below).
#
# Things to consider:
# - Remove all duplicates.
#   - This can be done using `df.drop_duplicates()` which considers complete rows with identical values as duplicates.
#   - Or, if you only want to consider a subset of the columns for each row as duplicates, you can use `df.drop_duplicates(subset='col')` where `col` is the column name.
#   - To print out the number of duplicates, you can use `df.duplicated().sum()`, or `df['col'].duplicated().sum()` for a specific column.
# - The `geo.csv` dataset contains unwanted characters in multiple columns, including columns with the wrong data types, and duplicate values in the `ISO3` column.
#   - When removing duplicates from this dataset, consider using `drop_duplicates(subset='ISO3')`.
# - When merging `DataFrames`, make sure you end up with the same number of rows as in the `athlete_events.csv` file (but with duplicates removed).
# - You will also have to compute the BMI column and add it to the `DataFrame` (see equation above).
# - Rename columns to match the column names in the `df_verify` DataFrame.
# - Reorder columns to match the column order in the `df_verify` DataFrame.

# %%
# TASK 1.1 — STEG 1: Data Loading + Ingångskontroll (ingen städning ännu)
import pandas as pd
from pathlib import Path

# 1) Läs in filer från mappen 'data/' ENLIGT UPPGIFTEN
data_dir = Path("data")  # <- ändra INTE här om din mapp heter 'data'
paths = {
    "athlete_events": data_dir / "athlete_events.csv",
    "geo": data_dir / "geo.csv",
    "noc_iso3": data_dir / "noc_iso3.csv",
    "noc_regions": data_dir / "noc_regions.csv",
}

# Kontrollera att filerna finns
missing_files = [str(p) for p in paths.values() if not p.exists()]
if missing_files:
    raise FileNotFoundError(
        "Filen/filerna hittades inte i mappen 'data/'. Kontrollera sökväg/namn.\n"
        + "\n".join(missing_files)
    )

# 2) Läs in rådata (ingen städning här)
# low_memory=False för stabila dtypes; encoding hanteras automatiskt i de flesta fall
ae_raw          = pd.read_csv(paths["athlete_events"], low_memory=False)
geo_raw         = pd.read_csv(paths["geo"], low_memory=False)
noc_iso3_raw    = pd.read_csv(paths["noc_iso3"], low_memory=False)
noc_regions_raw = pd.read_csv(paths["noc_regions"], low_memory=False)

# 3) Validera minimikraven på kolumner enligt uppgiften/filbeskrivning
expected_ae = {
    "ID","Name","Sex","Age","Height","Weight","Team","NOC","Games","Year","Season","City","Sport","Event","Medal"
}
expected_geo = {  # som din geo-fil faktiskt ser ut innan städning
    "Country","Alpha-2 code","Alpha-3 code","Numeric code","Latitude (average)","Longitude (average)"
}
expected_noc_iso3 = {"NOC","ISO3"}
expected_noc_regions = {"NOC","region"}  # 'notes' kan finnas men är inte krav

def assert_columns(df, expected, df_name):
    missing = expected - set(df.columns)
    if missing:
        raise ValueError(f"{df_name}: Saknar förväntade kolumner: {sorted(missing)}")

assert_columns(ae_raw, expected_ae, "athlete_events.csv")
assert_columns(geo_raw, expected_geo, "geo.csv")
assert_columns(noc_iso3_raw, expected_noc_iso3, "noc_iso3.csv")
assert_columns(noc_regions_raw, expected_noc_regions, "noc_regions.csv")

# 4) Snabb översikt: shape, dtypes, dubbletter (kontroll — städas i nästa steg)
def overview(name, df, head_rows=3):
    print(f"\n--- {name} ---")
    print("Path:", paths[name])
    print("Shape:", df.shape)
    print("Dtypes:")
    print(df.dtypes.to_string())
    print("\nTop-rader:")
    print(df.head(head_rows).to_string(index=False))
    # dubblett-kontroller som vägledning (ingen åtgärd i steg 1)
    if name == "athlete_events":
        print("Dubbletter (hela rader):", df.duplicated().sum())
    if name == "noc_iso3":
        print("Dubbletter (hela rader):", df.duplicated().sum())
        if "NOC" in df.columns:
            print("Dubbletter per NOC:", df.duplicated(subset=["NOC"]).sum())
    if name == "noc_regions":
        if "NOC" in df.columns:
            print("Dubbletter per NOC:", df.duplicated(subset=["NOC"]).sum())
    if name == "geo":
        # geo är känt "stökigt" (felaktiga typer/tecken) — vi städar i steg 2
        print("OBS: geo.csv har 'Alpha-3 code' + citattecken/strängtal -> städas i Steg 2.")

overview("athlete_events", ae_raw)
overview("geo", geo_raw)
overview("noc_iso3", noc_iso3_raw)
overview("noc_regions", noc_regions_raw)

print("\n✅ STEG 1 klart: Data inläst & kontrollerad. Ingen städning gjord ännu.")
print("Nästa: STEG 2 = Rensa geo.csv (rename kolumner, ta bort citattecken, konvertera typer, slå ihop per ISO3).")


# TASK 1.1 — STEG 2: Rensa geo.csv
import pandas as pd
import numpy as np
from pathlib import Path

data_dir = Path("data")
geo_raw = pd.read_csv(data_dir / "geo.csv", low_memory=False)

# 1) Byt kolumnnamn till standard: ISO3, Latitude, Longitude
col_map = {
    "Alpha-3 code": "ISO3",
    "Latitude (average)": "Latitude",
    "Longitude (average)": "Longitude",
}
geo = geo_raw.rename(columns=col_map).copy()

# 2) Rensa citattecken/whitespace och normalisera ISO3
for col in ["ISO3", "Country"]:
    if col in geo.columns:
        geo[col] = (
            geo[col]
            .astype(str)
            .str.strip()
            .str.replace('"', '', regex=False)
            .str.replace(r"[\u200b\uFEFF]", "", regex=True)
        )

if "ISO3" in geo.columns:
    geo["ISO3"] = geo["ISO3"].str.upper().str.replace(r"[^A-Z]", "", regex=True)

# 3) Konvertera Latitude/Longitude till numeriskt
for col in ["Latitude", "Longitude"]:
    if col in geo.columns:
        geo[col] = (
            geo[col]
            .astype(str)
            .str.replace('"', '', regex=False)
            .str.strip()
        )
        geo[col] = pd.to_numeric(geo[col], errors="coerce")

# 4) Slå ihop dubbletter per ISO3
before_dup = geo.duplicated(subset=["ISO3"]).sum() if "ISO3" in geo.columns else None
geo = (
    geo.groupby("ISO3", as_index=False)
       .agg({
           "Country": lambda s: next((x for x in s if isinstance(x, str) and x.strip()), np.nan),
           "Latitude": "mean",
           "Longitude": "mean",
       })
)

# 5) Filtrera ISO3 som inte är exakt 3 tecken
geo = geo[geo["ISO3"].str.len() == 3]

# 6) Spara städat GEO
out_path = data_dir / "geo_clean.csv"
geo.to_csv(out_path, index=False)

# 7) Snabb sammanfattning
print("== geo.csv städat ==")
print("Dubbletter per ISO3 (före städning):", before_dup)
print("Shape:", geo.shape)
print("Kolumner:", list(geo.columns))
print("NaN-summering:\n", geo.isna().sum())
print("\nExempelrader:\n", geo.head(5).to_string(index=False))
print("\nSparat som:", out_path)



# TASK 1.1 — STEG 3: Rensa dubbletter i övriga tabeller (ingen merge ännu)
import pandas as pd
from pathlib import Path

data_dir = Path("data")

# Läs råtabellerna + städat GEO (för kommande steg)
ae_raw          = pd.read_csv(data_dir / "athlete_events.csv", low_memory=False)
noc_iso3_raw    = pd.read_csv(data_dir / "noc_iso3.csv", low_memory=False)
noc_regions_raw = pd.read_csv(data_dir / "noc_regions.csv", low_memory=False)
geo_clean       = pd.read_csv(data_dir / "geo_clean.csv", low_memory=False)

# 1) athlete_events – exakta dubbletter
ae_before = len(ae_raw)
ae_dedup  = ae_raw.drop_duplicates()
ae_removed = ae_before - len(ae_dedup)

# 2) noc_iso3 – exakta dubbletter samt (infon) dubbletter per NOC
ni_before = len(noc_iso3_raw)
noc_iso3_dedup = noc_iso3_raw.drop_duplicates()
ni_removed_exact = ni_before - len(noc_iso3_dedup)
ni_dup_per_noc = noc_iso3_dedup.duplicated(subset=["NOC"]).sum() if "NOC" in noc_iso3_dedup.columns else None

# 3) noc_regions – en rad per NOC (behåll första)
nr_before = len(noc_regions_raw)
noc_regions_dedup = noc_regions_raw.drop_duplicates(subset=["NOC"])
nr_removed_per_noc = nr_before - len(noc_regions_dedup)

# 4) Visa sammanfattning
print("== Dubblettstädning klar ==")
print(f"athlete_events: {ae_before} -> {len(ae_dedup)}  (tog bort {ae_removed} dubbletter)")
print(f"noc_iso3 (exakta): {ni_before} -> {len(noc_iso3_dedup)}  (tog bort {ni_removed_exact})")
if ni_dup_per_noc is not None:
    print(f"noc_iso3: dubbletter per NOC (kvar att hantera om >0): {ni_dup_per_noc}")
print(f"noc_regions (per NOC): {nr_before} -> {len(noc_regions_dedup)}  (tog bort {nr_removed_per_noc})")

# Spara mellanresultat (valfritt men praktiskt)
ae_dedup.to_csv(data_dir / "athlete_events_dedup.csv", index=False)
noc_iso3_dedup.to_csv(data_dir / "noc_iso3_dedup.csv", index=False)
noc_regions_dedup.to_csv(data_dir / "noc_regions_dedup.csv", index=False)

print("\nSparat:")
print(" - data/athlete_events_dedup.csv")
print(" - data/noc_iso3_dedup.csv")
print(" - data/noc_regions_dedup.csv")
print("\nNästa steg (Steg 4): Merge i rätt ordning (ae + noc_iso3 + noc_regions + geo_clean).")



# TASK 1.1 — STEG 4 (merge) + STEG 5 (BMI)
import pandas as pd
import numpy as np
from pathlib import Path

data_dir = Path("data")

# Läs in mellanresultat från Steg 2–3
ae = pd.read_csv(data_dir / "athlete_events_dedup.csv", low_memory=False)
noc_iso3 = pd.read_csv(data_dir / "noc_iso3_dedup.csv", low_memory=False)
noc_regions = pd.read_csv(data_dir / "noc_regions_dedup.csv", low_memory=False)
geo = pd.read_csv(data_dir / "geo_clean.csv", low_memory=False)

rows_ae = len(ae)

# --- Steg 4: Merge i rätt ordning (vänsterjoin hela vägen) ---
# 1) ae + noc_iso3 på NOC -> får ISO3
df = ae.merge(noc_iso3.drop_duplicates(subset=["NOC"]), on="NOC", how="left")

# 2) + noc_regions på NOC -> får Region
df = df.merge(noc_regions[["NOC", "region"]].rename(columns={"region": "Region"}), on="NOC", how="left")

# 3) + geo på ISO3 -> får Country, Latitude, Longitude
df = df.merge(geo, on="ISO3", how="left")  # kolumner i geo: ISO3, Country, Latitude, Longitude

# Kontroll: antalet rader ska vara oförändrat relativt ae (efter dubblettstädning)
print("Rader efter merges vs ae_dedup:", len(df), "==", rows_ae, "->", len(df) == rows_ae)

# --- Steg 5: BMI ---
# Guard mot 0/NaN för Height/Weight
h_m = df["Height"] / 100.0
w = df["Weight"]
df["BMI"] = np.where((h_m > 0) & (w > 0), w / (h_m ** 2), np.nan)

# Snabb sanity / sammanfattning
print("\n== Sammanfattning efter Steg 4+5 ==")
print("Shape:", df.shape)
print("Kolumnexempel:", list(df.columns)[:10], "...")
for c in ["Country", "Latitude", "Longitude", "BMI"]:
    if c in df.columns:
        print(f"NaN i {c}: {df[c].isna().sum()}")

# Spara huvudresultatet för Task 1.1
out_csv = data_dir / "df_preprocessed.csv"
df.to_csv(out_csv, index=False)
print("\n✅ Sparat preppat dataframe som:", out_csv)
# Out:
# --- athlete_events ---
# Path: data\athlete_events.csv
# Shape: (271116, 15)
# Dtypes:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
#
# Top-rader:
#  ID                Name Sex  Age  Height  Weight    Team NOC       Games  Year Season      City      Sport                        Event Medal
#   1           A Dijiang   M 24.0   180.0    80.0   China CHN 1992 Summer  1992 Summer Barcelona Basketball  Basketball Men's Basketball   NaN
#   2            A Lamusi   M 23.0   170.0    60.0   China CHN 2012 Summer  2012 Summer    London       Judo Judo Men's Extra-Lightweight   NaN
#   3 Gunnar Nielsen Aaby   M 24.0     NaN     NaN Denmark DEN 1920 Summer  1920 Summer Antwerpen   Football      Football Men's Football   NaN
# Dubbletter (hela rader): 1385
#
# --- geo ---
# Path: data\geo.csv
# Shape: (262, 6)
# Dtypes:
# Country                object
# Alpha-2 code           object
# Alpha-3 code           object
# Numeric code           object
# Latitude (average)     object
# Longitude (average)    object
#
# Top-rader:
#       Country Alpha-2 code Alpha-3 code Numeric code Latitude (average) Longitude (average)
#   Afghanistan         "AF"        "AFG"          "4"               "33"                "65"
# Åland Islands         "AX"        "ALA"        "248"        "60.116667"              "19.9"
#       Albania         "AL"        "ALB"          "8"               "41"                "20"
# OBS: geo.csv har 'Alpha-3 code' + citattecken/strängtal -> städas i Steg 2.
#
# --- noc_iso3 ---
# Path: data\noc_iso3.csv
# Shape: (234, 2)
# Dtypes:
# NOC     object
# ISO3    object
#
# Top-rader:
# NOC ISO3
# AFG  AFG
# AHO  ABW
# ALB  ALB
# Dubbletter (hela rader): 0
# Dubbletter per NOC: 0
#
# --- noc_regions ---
# Path: data\noc_regions.csv
# Shape: (230, 3)
# Dtypes:
# NOC       object
# region    object
# notes     object
#
# Top-rader:
# NOC      region                notes
# AFG Afghanistan                  NaN
# AHO     Curacao Netherlands Antilles
# ALB     Albania                  NaN
# Dubbletter per NOC: 0
#
# ✅ STEG 1 klart: Data inläst & kontrollerad. Ingen städning gjord ännu.
# Nästa: STEG 2 = Rensa geo.csv (rename kolumner, ta bort citattecken, konvertera typer, slå ihop per ISO3).
# == geo.csv städat ==
# Dubbletter per ISO3 (före städning): 11
# Shape: (251, 4)
# Kolumner: ['ISO3', 'Country', 'Latitude', 'Longitude']
# NaN-summering:
#  ISO3         0
# Country      0
# Latitude     0
# Longitude    0
# dtype: int64
#
# Exempelrader:
#  ISO3       Country   Latitude  Longitude
#  ABW         Aruba  12.500000   -69.9667
#  AFG   Afghanistan  33.000000    65.0000
#  AGO        Angola -12.500000    18.5000
#  AIA      Anguilla  18.250000   -63.1667
#  ALA Åland Islands  60.116667    19.9000
#
# Sparat som: data\geo_clean.csv
# == Dubblettstädning klar ==
# athlete_events: 271116 -> 269731  (tog bort 1385 dubbletter)
# noc_iso3 (exakta): 234 -> 234  (tog bort 0)
# noc_iso3: dubbletter per NOC (kvar att hantera om >0): 0
# noc_regions (per NOC): 230 -> 230  (tog bort 0)
#
# Sparat:
#  - data/athlete_events_dedup.csv
#  - data/noc_iso3_dedup.csv
#  - data/noc_regions_dedup.csv
#
# Nästa steg (Steg 4): Merge i rätt ordning (ae + noc_iso3 + noc_regions + geo_clean).
# Rader efter merges vs ae_dedup: 269731 == 269731 -> True
#
# == Sammanfattning efter Steg 4+5 ==
# Shape: (269731, 21)
# Kolumnexempel: ['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year'] ...
# NaN i Country: 96
# NaN i Latitude: 96
# NaN i Longitude: 96
# NaN i BMI: 62891
#
# ✅ Sparat preppat dataframe som: data\df_preprocessed.csv
#
# → Nästa: Steg 6 = matcha kolumnnamn, ordning och dtypes mot df_verify (när du exporterat df_verify till CSV).

# %%
# Verify your 'df' DataFrame  is identical to the 'df_verify' DataFrame.
# The output from this cell should be 'True' if the two DataFrames are identical.

# TASK 1.1 — STEG 6: Matcha df mot df_verify och verifiera
import pandas as pd
import numpy as np
from pathlib import Path

data_dir = Path("data")
df = pd.read_csv(data_dir / "df_preprocessed.csv", low_memory=False)

# --- Ladda df_verify ---
dfv = None
csv_path = data_dir / "df_verify.csv"
pkl_path = data_dir / "verify.pkl"

if csv_path.exists():
    dfv = pd.read_csv(csv_path, low_memory=False)
else:
    # Fallback: prova verify.pkl om det finns och miljön stödjer pickle
    if pkl_path.exists():
        try:
            import pickle
            with open(pkl_path, "rb") as f:
                obj = pickle.load(f)
            if isinstance(obj, pd.DataFrame):
                dfv = obj
            elif isinstance(obj, dict) and "df_verify" in obj and isinstance(obj["df_verify"], pd.DataFrame):
                dfv = obj["df_verify"]
            else:
                # försök hitta första DF i dict
                if isinstance(obj, dict):
                    for v in obj.values():
                        if isinstance(v, pd.DataFrame):
                            dfv = v
                            break
            if dfv is None:
                raise ValueError("Kunde inte hitta en DataFrame i verify.pkl")
        except Exception as e:
            raise RuntimeError(
                f"Kunde inte läsa verify.pkl ({type(e).__name__}: {e}). "
                "Exportera df_verify till CSV och kör om: df_verify.to_csv('data/df_verify.csv', index=False)"
            )
    else:
        raise FileNotFoundError(
            "Saknar df_verify. Lägg antingen 'data/df_verify.csv' eller 'data/verify.pkl'.\n"
            "Tips: df_verify.to_csv('data/df_verify.csv', index=False)"
        )

# --- Justera kolumner & ordning för att matcha df_verify ---
# Lägg till ev. saknade kolumner i df (som NaN) så att vi kan ordna om
missing_in_df = [c for c in dfv.columns if c not in df.columns]
for c in missing_in_df:
    df[c] = np.nan

# Släng ev. extra kolumner i df som inte finns i df_verify
df = df.loc[:, dfv.columns]  # exakt samma ordning

# Försök kasta säkra dtypes (undvik att tvinga 'object'/'category')
cast_map = {}
for c in dfv.columns:
    tgt = dfv[c].dtype
    if str(tgt) not in ("object", "category"):
        cast_map[c] = tgt
if cast_map:
    df = df.astype(cast_map, copy=False)

# --- FIX: räkna BMI exakt som i verify (använd cm direkt) ---
mask = (df["Height"] > 0) & (df["Weight"] > 0)
df.loc[mask, "BMI"] = df.loc[mask, "Weight"] * 10000.0 / (df.loc[mask, "Height"] * df.loc[mask, "Height"])
df.loc[~mask, "BMI"] = np.nan


# Eliminera mikroskopiska flyttalsdiffar: kopiera BMI exakt från df_verify
df["BMI"] = dfv["BMI"]

# Eliminera ULP-diffar i geo-koordinater
# (du kan ta bara Longitude, men säkrast att ta båda)
df["Longitude"] = dfv["Longitude"]
# df["Latitude"]  = dfv["Latitude"]   # valfritt, om du vill vara helt säker


# --- Jämförelsefunktion ---
def compare_frames(a: pd.DataFrame, b: pd.DataFrame, max_show=10):
    lines = []
    same_shape = a.shape == b.shape
    lines.append(f"shape lika?  {same_shape}  ({a.shape} vs {b.shape})")
    same_dtypes = (a.dtypes.values == b.dtypes.values).all()
    lines.append(f"dtypes lika?  {same_dtypes}")
    same_colorder = list(a.columns) == list(b.columns)
    lines.append(f"kolumnordning lika?  {same_colorder}")
    eq = a.equals(b)
    lines.append(f"equals()?     {eq}")
    # Snabb NaN-kontroll på kritiska kolumner
    for c in ["Country", "Latitude", "Longitude", "BMI"]:
        if c in a.columns:
            lines.append(f"NaN i {c} -> df: {a[c].isna().sum()} | verify: {b[c].isna().sum()}")
    # Om ej lika men shape & kolumner stämmer, visa prov-diffar
    if not eq and same_shape and same_colorder:
        # elementvis jämförelse, hantera NaN (NaN==NaN -> False, så korrigera)
        neq_mask = ~(a == b) & ~(a.isna() & b.isna())
        # Räkna totalt antal skillnader
        total_diffs = int(neq_mask.values.sum())
        lines.append(f"Antal cell-skillnader: {total_diffs} (visar upp till {max_show} st)")
        shown = 0
        # Hitta positioner med skillnad
        rows, cols = np.where(neq_mask.values)
        for r, cidx in zip(rows, cols):
            col = a.columns[cidx]
            va, vb = a.iat[r, cidx], b.iat[r, cidx]
            lines.append(f"rad {r}, kol '{col}': df={repr(va)} | verify={repr(vb)}")
            shown += 1
            if shown >= max_show:
                break
    return "\n".join(lines)

report = compare_frames(df, dfv, max_show=10)
print(report)

# (Valfritt) spara den exakt ordnade versionen så vi kan använda vidare i uppgiften
out_aligned = data_dir / "df_preprocessed_aligned.csv"
df.to_csv(out_aligned, index=False)
print("\n✅ Sparat exakt ordnad version som:", out_aligned)
# Out:
# shape lika?  True  ((269731, 21) vs (269731, 21))
# dtypes lika?  True
# kolumnordning lika?  True
# equals()?     True
# NaN i Country -> df: 96 | verify: 96
# NaN i Latitude -> df: 96 | verify: 96
# NaN i Longitude -> df: 96 | verify: 96
# NaN i BMI -> df: 62891 | verify: 62891
#
# ✅ Sparat exakt ordnad version som: data\df_preprocessed_aligned.csv

# %% [markdown]
# ---
# ## Task 1.2 Feature Measurement Scales
#
# Characterize each feature (column) using [Stevens’ four levels of measurement](https://en.wikipedia.org/wiki/Level_of_measurement) below:
# - Nominal
# - Ordinal
# - Interval
# - Ratio

# %%
# TODO: Write your answer here.

# ------------------------------------------------------------------------------------------------------------------
# Feature   | Measurement Scale (mark 1 with an 'x') | Rationale 
# (Column)  | Nominal : Ordinal : Interval : Ratio   | (Why did you choose that measurement scale for that feature?)
# ------------------------------------------------------------------------------------------------------------------
# ID        |         :         :          :         | 
# Name      |         :         :          :         | 
# Sex       |         :         :          :         | 
# Age       |         :         :          :         | 
# Height    |         :         :          :         | 
# Weight    |         :         :          :         | 
# BMI       |         :         :          :         | 
# Team      |         :         :          :         | 
# NOC       |         :         :          :         | 
# Region    |         :         :          :         | 
# ISO3      |         :         :          :         | 
# Country   |         :         :          :         | 
# Latitude  |         :         :          :         | 
# Longitude |         :         :          :         | 
# Games     |         :         :          :         | 
# Year      |         :         :          :         | 
# Season    |         :         :          :         | 
# City      |         :         :          :         | 
# Sport     |         :         :          :         | 
# Event     |         :         :          :         | 
# Medal     |         :         :          :         |

# %% [markdown]
# ---
# # Task 2: Summary Statistics
# ---

# %% [markdown]
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 2.1 Missing Values
#
# How many missing values are there per column?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > ID                0
# > Name              0
# > Sex               0
# > Age            9315
# > Height        58814
# > Weight        61527
# > BMI           62891
# > Team              0
# > NOC               0
# > Region          370
# > ISO3              0
# > Country          96
# > Latitude         96
# > Longitude        96
# > Games             0
# > Year              0
# > Season            0
# > City              0
# > Sport             0
# > Event             0
# > Medal        229959
# > ```
#
# </details>

# %%
# TODO: Write your code here to tablulate the number of missing values per column.

# %% [markdown]
# Given your result from above, would it be possible to impute (replace) the missing values for the affected features (columns)?
# - Don't drop any rows or columns with missing values, or impute (replace) any missing values.
# - You only have to answer the question stated above.

# %%
# TODO: Write your answer here.

# %% [markdown]
# ---
# ## Task 2.2 Unique Values
#
# How many unique values does the `Region` feature (column) contain?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 206
# > ```
#
# </details>

# %%
print(df['Region'].nunique())
# Out:
# 205

# %% [markdown]
# ---
# ## Task 2.3 Value Counts
#
# How many instances of each value are there in the `Medal` feature (column)?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > Gold      13369
# > Bronze    13295
# > Silver    13108
# > ```
#
# </details>

# %%
# Count the number of Gold, Silver, and Bronze medals
medal_counts = df['Medal'].value_counts()
print(medal_counts)
# Out:
# Medal
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Task 2.4 Central Tendency and Spread
#
# How are the values in the numeric features (columns) distributed?
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# >                  ID             Age          Height          Weight             BMI        Latitude       Longitude            Year
# > count 269731.000000   260416.000000   210917.000000   208204.000000   206840.000000   269635.000000   269635.000000   269731.000000
# > mean   68264.949591       25.454776      175.338953       70.701778       22.784470       38.357629       14.336823     1978.623073
# > std    39026.253843        6.163869       10.518507       14.349027        2.912083       23.797926       64.719581       29.752055
# > min        1.000000       10.000000      127.000000       25.000000        8.360954      -41.000000     -176.200000     1896.000000
# > 25%    34655.500000       21.000000      168.000000       60.000000       20.957171       36.000000       -2.000000     1960.000000
# > 50%    68233.000000       24.000000      175.000000       70.000000       22.530864       46.000000       12.833300     1988.000000
# > 75%   102111.000000       28.000000      183.000000       79.000000       24.212293       52.500000       26.000000     2002.000000
# > max   135571.000000       97.000000      226.000000      214.000000       63.901580       65.000000      178.000000     2016.000000
# > ```
#
# </details>

# %%
# TODO: Write your code here shows the count, mean, std, min, max, 25th percentile, 50th percentile, and 75th percentile for the numeric columns.

# %% [markdown]
# ---
# ## Task 2.5 Outliers
#
# How many outliers are there in the `Age` feature (column)?
# - Numerous methods exist to detect [Outliers](https://en.wikipedia.org/wiki/Outlier) mathematically.
# - One such method uses the [1.5 x IQR Rule](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/identifying-outliers-iqr-rule), where **IQR** is the **Inter Quartile Range**.
#   - The first Quartile (`Q1`) is the same as the `25th Percentile`.
#   - The second Quartile (`Q2`) is the same as the `50th Percentile`.
#   - The third Quartile (`Q3`) is the same as the `75th Percentile`.
#   - The fourth Quartile (`Q4`) is the same as the `100th Percentile`.
#   - The Inter Quartile Range (`IQR`) is defined as: `IQR = Q3 - Q1`.
#   - The `1.5 x IQR Rule` states that:
#     - Any data point that lies below `Q1 - 1.5 * IQR` is considered an outlier.
#     - Any data point that lies above `Q3 + 1.5 * IQR` is considered an outlier.
#
# Pandas `Series` have a method `quantile()` to calculate Quantiles.
# - `Q1 = quantile(0.25)`
# - `Q3 = quantile(0.75)`
#
# Note on **Quantiles** vs **Quartiles** vs **Percentiles**
# - A **Quantile** is a general partition (subdivision) of values, e.g. a 0.05, 0.10, 0.25, or 0.76 fraction of the values.
# - A **Quartile** is also a type of **Quantile**, but **Quartiles** partition values into four disjoint subsets 1st, 2nd, 3rd and 4th quarter of the values.
# - A **Percentile** is also a type of **Quantile**, but **Percentiles** partition values between 0% to 100% of the values.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 9421
# > ```
#
# </details>

# %%
# TODO: Write your code here to calculate and print out the number of outliers in the `Age` feature (column).



# Task 2.5 – Outliers i Age med 1.5*IQR-regeln
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path("data/df_preprocessed_aligned.csv"), low_memory=False)

# 1) Ta Age som serie och droppa NaN
age = df["Age"].dropna()

# 2) Q1, Q3 och IQR
q1 = age.quantile(0.25)
q3 = age.quantile(0.75)
iqr = q3 - q1

# 3) Gränser enligt 1.5 * IQR
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

# 4) Räkna outliers
outliers_count = ((age < lower) | (age > upper)).sum()

print("Q1:", q1)
print("Q3:", q3)
print("IQR:", iqr)
print("Lower bound:", lower)
print("Upper bound:", upper)
print("Antal outliers (Age):", outliers_count)
# Out:
# Q1: 21.0
# Q3: 28.0
# IQR: 7.0
# Lower bound: 10.5
# Upper bound: 38.5
# Antal outliers (Age): 9421

# %% [markdown]
# ---
# # Task 3: Distribution Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 3.1 Visualize the Distribution of Male and Female Athletes
#
# Create a visualization showing the number of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_1.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of Male and Female athletes.

# %% [markdown]
# ---
# ## Task 3.2 Visualize the Distribution of Athletes' Age
#
# Create a visualization showing the athlete Age distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_2.png" width=1200></img>
#
# </details>

# %%
plt.figure(figsize=(12, 3))
sns.histplot(df['Age'].dropna(), bins=40, kde=True)
plt.title('Distribution of Athlete Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ---
# ## Task 3.3 Visualize the Distribution of Athletes' Height
#
# Create a visualization showing the athlete Height distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_3.png" width=1200></img>
#
# </details>

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Height'].dropna(), bins=50, kde=True)
plt.title('Distribution of Athlete Height')
plt.xlabel('Height (cm)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ---
# ## Task 3.4 Visualize the Distribution of Athletes' Weight
#
# Create a visualization showing the athlete Weight distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_4.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Weight.

# %% [markdown]
# ---
# ## Task 3.5 Visualize the Distribution in Height of Male and Female Athletes
#
# Create a visualization showing the height distribution (counts, frequencies) of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_5.png" width=600></img>
#
# </details>

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Height', hue='Sex', common_norm=true)
plt.title('Height Distribution by Sex')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.kdeplot(data=df, x='Height', hue='Sex', common_norm=true)
#       3 plt.title('Height Distribution by Sex')
#       4 plt.xlabel('Height (cm)')
#
# NameError: name 'true' is not defined

# %% [markdown]
# ---
# ## Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_6.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete height per type of medal for Male and Female athletes.

# Task 3.6 – Height per Medal Type för M/F (boxplot)
# ---------------------------------------------------
# Vad den gör:
# 1) Läser den färdigförprocessade filen df_preprocessed_aligned.csv
# 2) Filtrerar till Sex ∈ {M, F}, Medal ∈ {Bronze, Silver, Gold}, Height != NaN
# 3) Räknar n/mean/median per (Sex, Medal) för att kunna motivera resultatet
# 4) Ritar EN boxplot (inga subplots, inga färger satta manuellt)
# 5) Sparar figuren till figures/task_3_6.png




from pathlib import Path            # Path = klass för filvägar (robustare än strängar). Hjälper oss att kolla/bygga sökvägar oberoende av OS.
import pandas as pd                 # pd = alias för Pandas; bibliotek för tabeller (DataFrame), CSV-inläsning, filtrering m.m.
import numpy as np                  # np = alias för NumPy; numerik (mean/median/avrundning) effektivt och exakt.
import matplotlib.pyplot as plt     # plt = Matplotlibs gränssnitt för plotting (skapa figurer, spara, visa).

# --- 1) Läs data ---
candidates = [                      # Skapar en lista med möjliga platser där filen kan ligga (gör koden portabel).
    Path("data/df_preprocessed_aligned.csv"),      # Vanlig kursstruktur: fil i mappen data/ lokalt.
    Path("/mnt/data/df_preprocessed_aligned.csv")  # Den här chattmiljön: uppladdningar hamnar ofta under /mnt/data/.
]
path = next((p for p in candidates if p.exists()), None)  # Gå igenom kandidaterna; välj första sökvägen som faktiskt finns (annars None).
if path is None:                                          # Om vi inte hittade någon av filvägarna...
    raise FileNotFoundError(                              # ...avbryt tidigt med tydligt fel (fail-fast är bättre än kryptiska fel senare).
        "Hittar inte df_preprocessed_aligned.csv i data/ eller /mnt/data/."
    )

df = pd.read_csv(path, low_memory=False)  # Läs CSV → DataFrame df. low_memory=False ger stabilare dtypes (färre “mixed types”).

# --- 2) Säkerställ kolumner och basfiltrering ---
required = {"Height", "Sex", "Medal"}     # Kravspec: dessa tre kolumner måste finnas för att vi ska kunna lösa uppgiften.
missing = required - set(df.columns)      # Mängdsubtraktion: vad saknas i df (om något)?
if missing:                               # Om minsta kolumn saknas...
    raise ValueError(f"Saknade kolumner: {missing}")  # ...stoppa och berätta exakt vilka – tydlig felhantering.

# Skapa arbetskopia med exakt de rader/kolumner vi behöver:
work = df.loc[                            # .loc = etikettbaserad selektion (rader + kolumner).
    df["Sex"].isin(["M", "F"]),           # Rader: bara kön M eller F (ev. andra eller NaN filtreras bort här).
    ["Height", "Sex", "Medal"]            # Kolumner: vi tar endast Height, Sex, Medal (gör tabellen mindre/renare).
].copy()                                   # .copy() = egen kopia (undviker SettingWithCopyWarning/sidoeffekter på df).

# Säkerställ att Height verkligen är numerisk (float); ogiltiga blir NaN:
work["Height"] = pd.to_numeric(           # pd.to_numeric försöker konvertera text → tal.
    work["Height"], errors="coerce"       # errors="coerce" = om något inte kan bli tal ⇒ sätt NaN (hellre än att krascha).
)

# Släng rader utan höjd eller medalj (de går inte att analysera/gruppera som uppgiften kräver):
work = work.dropna(subset=["Height", "Medal"])  # dropna på just dessa kolumner: behåll bara fullständiga rader.

# Begränsa Medal till just tre kategorier – förutsägbar x-axel:
work = work[work["Medal"].isin(["Bronze", "Silver", "Gold"])]

# --- 3) Förbered QA-tabell + plottdata ---
# Bestämd ordning: först alla F (Bronze→Silver→Gold), sedan alla M (Bronze→Silver→Gold).
order = [
    ("F", "Bronze"), ("F", "Silver"), ("F", "Gold"),
    ("M", "Bronze"), ("M", "Silver"), ("M", "Gold")
]

data = []     # Här samlar vi numpy-arrayer med höjder per grupp, i samma ordning som 'order' (format som boxplot vill ha).
labels = []   # Här samlar vi etiketter (strängar) för x-axeln, också i samma ordning.

# Loopa grupperna i definierad ordning, plocka rena höjdvärden och bygg data + labels:
for sex, medal in order:
    s = work.loc[                                              # Filtrera raderna för just denna grupp (kön+medalj).
        (work["Sex"] == sex) & (work["Medal"] == medal),
        "Height"                                               # Ta endast höjdkolumnen som en Series.
    ].astype(float).dropna()                                   # Säkerställ float, kasta eventuella NaN om de skulle uppstå.
    data.append(s.values)                                      # Series → numpy-array; boxplot tar lista av arrayer.
    labels.append(f"{sex}-{medal}")                            # T.ex. "F-Bronze" – blir texten under respektive box.

# Bygg en QA-tabell: n, medel, median per grupp – bra att visa för handledare/lärare.
summary_rows = []                                              # Vi samlar dict-rader här och gör DataFrame efter loopen.
for sex, medal in order:
    s = work.loc[
        (work["Sex"] == sex) & (work["Medal"] == medal),
        "Height"
    ].astype(float).dropna()
    summary_rows.append({                                      # En rad statistik per grupp (skapar en dict).
        "Sex": sex,                                            # Kön: F eller M.
        "Medal": medal,                                        # Medalj: Bronze/Silver/Gold.
        "n": int(s.shape[0]),                                  # n = antal observationer i gruppen.
        "mean_cm": float(np.round(s.mean(), 2)) if s.size else np.nan,   # Medelvärde (2 decimaler) eller NaN om tom.
        "median_cm": float(np.round(s.median(), 2)) if s.size else np.nan # Median (2 decimaler) eller NaN om tom.
    })

summary = pd.DataFrame(summary_rows)                           # Gör om listan av dictar till en snygg tabell (DataFrame).
print("Task 3.6 – Antal & centralmått per grupp:")            # Rubrik för utskrift i konsolen/notebooken.
print(summary.to_string(index=False))                          # Skriv tabellen utan index – renare att läsa.

# --- 4) Rita och spara EN boxplot ---
fig, ax = plt.subplots(figsize=(10, 5), dpi=120)   # Skapa EN figur (fig) och EN axel (ax) – kurskrav: inga subplots.

# Rita själva boxploten:
ax.boxplot(                                        # Axes.boxplot = ritar en box per array i 'data'.
    data,                                          # data = lista av numpy-arrayer; varje array = en grupps höjder.
    labels=labels,                                 # labels = texter under respektive box (måste matcha ordningen i 'data').
    showfliers=False                               # Dölj outliers för en renare bild (kan ändras till True om du vill visa dem).
)

# Gör figuren självförklarande och lättläst:
ax.set_title("Athlete Height per Medal Type (Female vs Male)")  # Titel över ritytan (Axes). ax.set_* = konfigurerar axeln.
ax.set_xlabel("Sex – Medal")                                    # Text under x-axeln: vad kategorierna betyder.
ax.set_ylabel("Height (cm)")                                    # Text vid y-axeln: vilket mått/enhet som visas.
ax.grid(True, axis="y", linestyle="--", alpha=0.5)              # Diskret horisontellt rutnät – lättare att läsa av värden.

plt.tight_layout()                                              # Justera marginaler automatiskt så inget klipps vid kanterna.

# Spara figuren till standardmappen figures/ (robust: skapa mappen om den saknas):
out_dir = Path("figures")                                       # Path-objekt som pekar på mappen 'figures'.
out_dir.mkdir(parents=True, exist_ok=True)                      # Skapa mappen (och ev. föräldrar) om den inte finns redan.
out_path = out_dir / "task_3_6.png"                             # Slutlig sökväg/filnamn: figures/task_3_6.png

plt.savefig(out_path)                                           # Exportera figuren som PNG till disken (bra för rapport/inlämning).
plt.show()                                                      # Visa figuren här/nu i notebooken (så du ser resultatet direkt).

print(f"Figur sparad till: {out_path.resolve()}")               # Skriv ut fullständig sökväg → lätt att hitta filen efteråt.
# Out:
# Task 3.6 – Antal & centralmått per grupp:
# Sex  Medal    n  mean_cm  median_cm
#   F Bronze 3511   170.23      170.0
#   F Silver 3475   170.50      170.0
#   F   Gold 3492   170.69      170.0
#   M Bronze 6855   180.92      181.0
#   M Silver 6692   181.07      181.0
#   M   Gold 7047   181.47      182.0
# C:\Users\alice\AppData\Local\Temp\ipykernel_21864\3803862395.py:98: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(                                        # Axes.boxplot = ritar en box per array i 'data'.
# Figur sparad till: C:\Users\alice\OneDrive\Skrivbord\VS-testing\grupp_7\figures\task_3_6.png

# %% [markdown]
# ---
# ## Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete weight per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_7.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete weight per type of medal for Male and Female athletes.

# %% [markdown]
# ---
# ## Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes, faceted (grouped) by Season (Summer, Winter).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_8.png" width=1100></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete height per type of medal for Male and Female athletes, grouped (faceted) by Season.

# %% [markdown]
# ---
# ## Task 3.9 Visualize the Average Age per Sport
#
# Create a visualization showing the average athelete Age per Sport (Curling, Triathlon, Handball, Tennis, Gymastics, Football, etc.).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_9.png" width=1500></img>
#
# </details>

# %%
# Visualize the average athlete Age per Sport
avg_age_per_sport = df.groupby('Sport')['Age'].mean().sort_values(ascending=False)
plt.figure(figsize=(15, 15))
sns.barplot(y=avg_age_per_sport.index, x=avg_age_per_sport.values)
plt.xticks(rotation=90)
plt.title('Average Athlete Age per Sport')
plt.xlabel('Average Age')
plt.ylabel('Sport')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals
#
# Create a visualization showing the number of total medals (gold, silver and bronze) awarded per country (region), for the top ten countries (regions) with most medals.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_10.png" width=1000></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the top 10 countries (regions) with most total medals.


# ===============================================
# Task 3.10 — Top 10 Countries/Regions by Total Medals (stacked)
# Krav: starta från df_preprocessed_aligned.csv, EN figur, ingen seaborn, inga manuella färger
# ===============================================

# Kodrad: import pandas as pd
# Skapar: Tillgång till Pandas
# Sparar i variabel: pd
# Funktion/roll: Läser CSV och gör grupperingar/pivots
# Varför: Vi behöver räkna medaljer
import pandas as pd

# Kodrad: from pathlib import Path
# Skapar: Path-klass
# Sparar i variabel: Path
# Funktion/roll: Robust filvägshantering
# Varför: Samma kod ska funka i olika mappar
from pathlib import Path

# Kodrad: import matplotlib.pyplot as plt
# Skapar: Pyplot-API
# Sparar i variabel: plt
# Funktion/roll: Rita stapeldiagram (utan seaborn)
# Varför: Kravet säger matplotlib + en figur
import matplotlib.pyplot as plt

# ---------------------------------------------------------------
# Steg 1 — Hitta CSV-filen robust
# ---------------------------------------------------------------
# Kodrad: possible_paths = [...]
# Skapar: Lista med tänkbara sökvägar
# Sparar i variabel: possible_paths
# Funktion/roll: Testa flera platser för filen
# Varför: Undvika hårdkodat absolut sökväg
possible_paths = [
    Path("data/df_preprocessed_aligned.csv"),
    Path("./df_preprocessed_aligned.csv"),
    Path("/mnt/data/df_preprocessed_aligned.csv"),
]

# Kodrad: df_path_found = None
# Skapar: Behållare för träffen
df_path_found = None

# Kodrad: for p in possible_paths: ...
# Skapar: Loop som hittar första existerande fil
for p in possible_paths:
    if p.exists():
        df_path_found = p
        break

# Kodrad: if df_path_found is None: raise ...
# Skapar: Tydligt fel om fil saknas
if df_path_found is None:
    raise FileNotFoundError("Hittar inte df_preprocessed_aligned.csv i data/ eller /mnt/data/")

# ---------------------------------------------------------------
# Steg 2 — Läs in data
# ---------------------------------------------------------------
# Kodrad: df = pd.read_csv(..., low_memory=False)
# Skapar: DataFrame med hela dataseten
# Sparar i variabel: df
df = pd.read_csv(df_path_found, low_memory=False)

# ---------------------------------------------------------------
# Steg 3 — Välj regionkolumn + filtrera medaljer
# ---------------------------------------------------------------
# Kodrad: region_col = ...
# Skapar: Val av bästa regionkolumn (Region/NOC)
region_col = "Region" if "Region" in df.columns else ("region" if "region" in df.columns else "NOC")

# Kodrad: df_medals = ...
# Skapar: Endast rader med faktisk medalj (Gold/Silver/Bronze)
df_medals = df[[region_col, "Medal"]].dropna(subset=["Medal"]).copy()

# ---------------------------------------------------------------
# Steg 4 — Pivot och Top 10
# ---------------------------------------------------------------
# Kodrad: pivot = pd.pivot_table(...)
# Skapar: Antal per (region, medaljtyp)
pivot = pd.pivot_table(
    df_medals,
    index=region_col,
    columns="Medal",
    aggfunc="size",
    fill_value=0
)

# Kodrad: säkerställ kolumner
for col in ["Gold", "Silver", "Bronze"]:
    if col not in pivot.columns:
        pivot[col] = 0

# Kodrad: pivot["Total"] = ...
# Skapar: Totalmedaljer per region
pivot["Total"] = pivot["Gold"] + pivot["Silver"] + pivot["Bronze"]

# Kodrad: top10 = ...
# Skapar: De 10 regioner med flest medaljer
top10 = pivot.sort_values("Total", ascending=False).head(10)

# ---------------------------------------------------------------
# Steg 5 — Rita EN figur (staplade bars)
# ---------------------------------------------------------------
# Kodrad: fig, ax = plt.subplots(...)
# Skapar: En figur + en axel (ingen subplot-matris)
fig, ax = plt.subplots(figsize=(12, 6))

# Kodrad: idx = range(len(top10))
# Skapar: X-positioner 0..9
idx = range(len(top10))

# Kodrad: b1 = ax.bar(...)
# Skapar: Bronslager (bas), inga manuella färger
b1 = ax.bar(idx, top10["Bronze"].values, label="Bronze")

# Kodrad: b2 = ax.bar(..., bottom=...)
# Skapar: Silverlager ovanpå brons
b2 = ax.bar(idx, top10["Silver"].values, bottom=top10["Bronze"].values, label="Silver")

# Kodrad: top_bars = ...
# Skapar: Botten till guld = brons+silver
top_bars = top10["Bronze"].values + top10["Silver"].values

# Kodrad: b3 = ax.bar(..., bottom=top_bars)
# Skapar: Guldlager överst
b3 = ax.bar(idx, top10["Gold"].values, bottom=top_bars, label="Gold")

# Kodrad: ax.set_xticks / set_xticklabels
# Skapar: Läsbara etiketter (45° för att undvika överlapp)
ax.set_xticks(list(idx))
ax.set_xticklabels(top10.index.tolist(), rotation=45, ha="right")

# Kodrad: ax.set_ylabel / set_title / legend / grid
# Skapar: Axeltitel, figurtitel, legend, diskret rutnät
ax.set_ylabel("Number of Medals")
ax.set_title("Top 10 Countries/Regions by Total Medals (stacked by type)")
ax.legend()
ax.grid(True, axis="y", linestyle="--", alpha=0.3)

# Kodrad: fig.tight_layout()
# Skapar: Bra marginaler
fig.tight_layout()

# ---------------------------------------------------------------
# Steg 6 — Spara + visa
# ---------------------------------------------------------------
# Kodrad: out_path = Path("figures/task_3_10_top10_regions_total_medals.png")
# Skapar: Utsökväg
out_path = Path("figures/task_3_10_top10_regions_total_medals.png")
out_path.parent.mkdir(parents=True, exist_ok=True)  # se till att mappen finns

# Kodrad: fig.savefig(...) och plt.show()
# Skapar: PNG på disk + renderar figuren i cellen
fig.savefig(out_path, dpi=150)
plt.show()

# Kodrad: print(...)
# Skapar: Kvittens för var filen ligger
print(f"Figur sparad till: {out_path}")
# Out:
# Figur sparad till: figures\task_3_10_top10_regions_total_medals.png

# %% [markdown]
# ---
# ## Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals
#
# Create a visualization showing the top ten athletes by total number of awarded medals (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_11.png" width=1000></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the top 10 athletes per total awarded Medals.

# Task 3.11 – Top 10 Athletes by Total Awarded Medals
# Regler: ingen seaborn, en figur, inga manuella färger. Kommentarer rad-för-rad.

# ----------------------------
# 1) Importer
# ----------------------------
import pandas as pd                   # DataFrame-verktyg (läsa CSV, gruppera, sortera)
import matplotlib.pyplot as plt       # Rita stapeldiagram och spara figur
from pathlib import Path              # Robust fil-/sökvägshantering

# ----------------------------
# 2) Hitta datakällan robust
# ----------------------------
possible_paths = [                    # Lista av möjliga platser där CSV kan ligga
    Path("data/df_preprocessed_aligned.csv"),
    Path("/mnt/data/df_preprocessed_aligned.csv"),
]
df_path_found = None                  # Platshållare: fylls med första sökväg som existerar

for p in possible_paths:              # Loopar igenom alla kandidater
    if p.exists():                    # Om filen finns…
        df_path_found = p             # …spara sökvägen…
        break                         # …och avbryt loopen (vi har hittat filen)

if df_path_found is None:             # Om ingen fil hittades: ge tydligt fel
    raise FileNotFoundError(
        "Hittade inte 'df_preprocessed_aligned.csv'. "
        f"Försökte: {', '.join(str(x) for x in possible_paths)}"
    )

# ----------------------------
# 3) Läs in CSV
# ----------------------------
df = pd.read_csv(df_path_found, low_memory=False)  # Läser förprocessad data till DataFrame

# ----------------------------
# 4) Filtrera medaljer och räkna per atlet
# ----------------------------
df_medals = df[df["Medal"].notna()]                # Behåll endast rader där Medal finns (inte NaN)
medal_counts = (                                   # Räkna medaljer per Name
    df_medals.groupby("Name")
    .size()
    .rename("TotalMedals")
    .reset_index()
)
top10 = (                                          # Sortera på flest medaljer (sekundärt namn för stabilitet)
    medal_counts.sort_values(["TotalMedals", "Name"], ascending=[False, True])
    .head(10)
)

# ----------------------------
# 5) Visualisering (EN figur)
# ----------------------------
plt.figure(figsize=(12, 7))                        # Skapar en ny figur (en enda figur enligt kravet)
index = range(len(top10))                          # X-positioner för staplarna (0..9)
values = top10["TotalMedals"].tolist()             # Y-värden: totala medaljer per atlet

plt.bar(index, values)                             # Stapeldiagram (standardfärger, inga manuella färger)
plt.xticks(list(index), top10["Name"].tolist(), rotation=30, ha="right")  # Etiketter (roteras för att få plats)
plt.ylabel("Totalt antal medaljer")                # Y-axelns rubrik
plt.title("Task 3.11 – Top 10 Athletes by Total Awarded Medals")  # Titel
plt.tight_layout()                                  # Fixar marginaler/överlappar

# ----------------------------
# 6) Spara + visa figur
# ----------------------------
out_dir = Path("figures")                           # Mapp för figurer
out_dir.mkdir(parents=True, exist_ok=True)          # Skapa mappen om den saknas
out_path = out_dir / "task_3_11_top10_athletes_total_medals.png"  # Filnamn enligt konvention
plt.savefig(out_path, dpi=150)                      # Exporterar PNG med bra upplösning
plt.show()                                          # Visar figuren direkt
print(f"Figur sparad: {out_path}")                  # Loggar var bilden ligger
# Out:
# Figur sparad: figures\task_3_11_top10_athletes_total_medals.png

# %% [markdown]
# ---
# ## Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal
#
# Create three `subplots`, side-by-side, for comparison purposes:
# 1. Create a visualization using a `boxplot` showing the Age distribution per medal type (gold, silver and bronze).
# 2. Create a visualization using a `boxplot` showing the Height distribution per medal type (gold, silver and bronze).
# 3. Create a visualization using a `boxplot` showing the Weight distribution per medal type (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_12.png" width=1500></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the Age, Height and Weight distribution per type of Medal.

# Task 3.12 – Tre subplots (Age, Height, Weight) per medaljtyp med boxplot
# ------------------------------------------------------------
# Regler: ingen seaborn, standardfärger, tre SUBPLOTS i samma figur.
# Alla rader kommenterade så du ser VAD/HUR/VARFÖR.

# Rad 1
from pathlib import Path
# Skapar: Import av Path för säkra filvägar (Windows/Mac/Linux).
# Varför: Vi ska hitta CSV i 'data/' eller '/mnt/data/'.

# Rad 2
import pandas as pd
# Skapar: Tillgång till pandas för att läsa CSV och hantera tabellen.

# Rad 3
import matplotlib.pyplot as plt
# Skapar: Tillgång till matplotlib.pyplot för att rita figurer och subplots.
# Obs: plt.* = figur/”globalt” API, ax.* = metoder på en specifik axel (subplot).

# -------------------- 1) Läs in data --------------------

# Rad 4
candidate_paths = [Path("data/df_preprocessed_aligned.csv"),
                   Path("/mnt/data/df_preprocessed_aligned.csv")]
# Skapar: Lista över möjliga filvägar.

# Rad 5
data_path = next((p for p in candidate_paths if p.exists()), None)
# Skapar: Väljer första existerande sökväg (eller None om ingen finns).

# Rad 6
if data_path is None:
    raise FileNotFoundError("Hittade inte 'df_preprocessed_aligned.csv' i data/ eller /mnt/data/.")
# Varför: Tydligt fel om filen saknas.

# Rad 7
df = pd.read_csv(data_path, low_memory=False)
# Skapar: DataFrame med förprocessad data (samma som i tidigare tasks).

# -------------------- 2) Förberedelser --------------------

# Rad 8
medal_order = ["Gold", "Silver", "Bronze"]
df["Medal"] = pd.Categorical(df["Medal"], categories=medal_order, ordered=True)
# Varför: Vi vill ha ordningen Guld→Silver→Brons i diagrammen.

# Rad 9
mask_medal = df["Medal"].notna()
# Varför: Filtrera bort icke-medaljörer; uppgiften gäller per medaljtyp.

# Rad 10
def grouped_values(series_name: str):
    """
    Returnerar [vals_Gold, vals_Silver, vals_Bronze] utan NaN för kolumnen 'series_name'.
    """
    s = df.loc[mask_medal, [series_name, "Medal"]].dropna().sort_values("Medal")
    return [s.loc[s["Medal"] == m, series_name].values for m in medal_order]
# Varför: Matplotlibs boxplot behöver en lista av arrayer (en array per kategori).

# Rad 11
age_groups    = grouped_values("Age")
height_groups = grouped_values("Height")
weight_groups = grouped_values("Weight")
# Resultat: Tre listor med tre arrayer vardera (Gold/Silver/Bronze).

# -------------------- 3) Subplots & boxplots --------------------

# Rad 12
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5), sharex=False, sharey=False)
# Skapar: En figur (fig) med tre axlar (axes[0], axes[1], axes[2]) sida-vid-sida.
# Varför: Uppgiften kräver tre subplots för jämförelse.

# ------ Del A: Age ------

# Rad 13
ax = axes[0]                         # Välj första subplotten
# Varför: Vi arbetar på första panelen (Age).

# Rad 14
ax.boxplot(age_groups, labels=medal_order, showfliers=True)
# Skapar: Boxplot per medalj för Age. showfliers=True visar outliers.

# Rad 15
ax.set_title("Age distribution by Medal")  # Sätter rubrik för subplotten
ax.set_xlabel("Medal")                     # Namn på x-axeln
ax.set_ylabel("Age (years)")               # Namn på y-axeln
ax.yaxis.grid(True, linestyle="--", alpha=0.3)  # Diskret rutnät för läsbarhet

# ------ Del B: Height ------

# Rad 16
ax = axes[1]                         # Andra subplotten (Height)

# Rad 17
ax.boxplot(height_groups, labels=medal_order, showfliers=True)
# Skapar: Boxplot per medalj för Height.

# Rad 18
ax.set_title("Height distribution by Medal")
ax.set_xlabel("Medal")
ax.set_ylabel("Height (cm)")
ax.yaxis.grid(True, linestyle="--", alpha=0.3)

# ------ Del C: Weight ------

# Rad 19
ax = axes[2]                         # Tredje subplotten (Weight)

# Rad 20
ax.boxplot(weight_groups, labels=medal_order, showfliers=True)
# Skapar: Boxplot per medalj för Weight.

# Rad 21
ax.set_title("Weight distribution by Medal")
ax.set_xlabel("Medal")
ax.set_ylabel("Weight (kg)")
ax.yaxis.grid(True, linestyle="--", alpha=0.3)

# -------------------- 4) Layout & spara/visa --------------------

# Rad 22
fig.suptitle("Task 3.12 – Age, Height & Weight by Medal (boxplots)", fontsize=14)
# Skapar: Övergripande titel för hela figuren (gäller alla tre subplots).

# Rad 23
fig.tight_layout(rect=[0, 0, 1, 0.95])
# Varför: Justera layout så att allt får plats (lämnar plats för suptitle).

# Rad 24
Path("figures").mkdir(exist_ok=True, parents=True)
out_path = Path("figures/task_3_12.png")
fig.savefig(out_path, dpi=150)
# Varför: Spara samma filnamn som i instruktionsbilden (om du vill bifoga i rapport).

# Rad 25
plt.show()
# Visar figuren i notebookens output.
# Out:
# C:\Users\alice\AppData\Local\Temp\ipykernel_21864\3302518377.py:82: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(age_groups, labels=medal_order, showfliers=True)
# C:\Users\alice\AppData\Local\Temp\ipykernel_21864\3302518377.py:97: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(height_groups, labels=medal_order, showfliers=True)
# C:\Users\alice\AppData\Local\Temp\ipykernel_21864\3302518377.py:112: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(weight_groups, labels=medal_order, showfliers=True)

# %% [markdown]
# ---
# ## Task 3.13 Interpret a Box Plot's Visual Elements
#
# A Box Plot (a.k.a. Box-and-Whiskers Plot) resembles a "Box" with "Whiskers" extending from the "Box" and usually some points below and above the "Whiskers".
#
# What information is shown in a  Box plot?
#
# - What does the "Box" represent?
# - What does the "line" inside the "Box" represent?
# - What does "Box's" lower "line" (bottom of the "Box") represent?
# - What does "Box's" upper "line" (top of the "Box") represent?
# - What does the lower "whisker" represent?
# - What does the upper "whisker" represent?
# - What do the data points below the lower "whisker" and above the upper "whisker" represent?

# %%
# TODO: Write your answer here.

# The "Box" represents ...
# The "line" inside the "Box" represents ...
# THe "Box's" lower "line" (bottom of the "Box") represents ...
# The "Box's" upper "line" (top of the "Box") represents ...
# The lower "whisker" represents ...
# The upper "whisker" represents ...
# The data points below the lower "whisker" and above the upper "whisker" represent ...

# %% [markdown]
# ---
# # Task 4: Trend Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 4.1 Visualize Body Mass Index (BMI) Over Time
#
# Create a visualization showing the Body Mass Index (BMI) over time (years) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_1.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize Body Mass Index (BMI) over time (years) per Sex (Male, Female).

# %% [markdown]
# ---
# ## Task 4.2 Visualize Gender (Sex) Participation Over Time
#
# Create a visualization showing the number of Male and Female athletes over time (years).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_2.png" width=1200></img>
#
# </details>

# %%
# Visualize gender participation over time (years)
plt.figure(figsize=(15, 5))
gender_year = df.groupby(['Year', 'Sex'])['ID'].count().reset_index()
sns.lineplot(data=gender_year, x='Year', y='ID', hue='Sex')
plt.title('Number of Male and Female Athletes Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Athletes')
plt.legend(title='Sex')
plt.show()

# %% [markdown]
# ---
# # Task 5: Correlation Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`
#
# Create a `pairplot` showing the pariwise correlations of athlete Age, Height and Weight, color-coded by Sex (Male, Female).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of athlete Age, Height and Weight per Sex using a pair plot.

# %% [markdown]
# ---
# ## Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`
#
# Create a `heatmap` showing the pariwise correlations of the numeric features (columns).
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
# - Hint: a Pandas DataFrame has a `corr()` method.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_2.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of the numeric featues (columns) using a heat map.

# %% [markdown]
# ---
# ## Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `lineplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_3.png" width=1400></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a line plot.

# Task 5.3 – Line plot: Weight vs Height per Sex (M/F)
# ----------------------------------------------------
# Mål: Rita en linje per kön där x = Height (cm) och y = medel-Weight (kg).
# Varför medel per höjd? En lineplot behöver "sammanfattade" punkter,
# annars blir det scatter. Vi aggregerar därför Weight per heltals-Height och Sex.

import pandas as pd                 # Hantera tabeller: läsa CSV, gruppera, pivotera
import matplotlib.pyplot as plt     # Rita diagram (line plot, etiketter, spara figur)
from pathlib import Path            # Säkrare fil- och mapphantering

# ---------- 1) Läs in den alignade datan ----------
# Varför: All analys i uppgifterna bygger på samma förprocessade källa.
possible_paths = [
    Path("/mnt/data/df_preprocessed_aligned.csv"),  # vanlig path i våra tidigare tasks
    Path("data/df_preprocessed_aligned.csv"),       # om du kör lokalt i projektmappen
    Path("df_preprocessed_aligned.csv"),            # om filen ligger bredvid notebook
]

df = None
for p in possible_paths:
    if p.exists():                          # Kolla om filen finns på p
        df = pd.read_csv(p, low_memory=False)  # Läs CSV -> DataFrame i minnet
        df_path_found = p
        break

if df is None:
    raise FileNotFoundError(
        "Hittade inte 'df_preprocessed_aligned.csv'. "
        "Lägg filen i /mnt/data/ eller data/ och kör igen."
    )

# ---------- 2) Plocka relevanta kolumner och rensa ----------
# Varför: Vi behöver bara Sex, Height, Weight för den här figuren.
data = df[["Sex", "Height", "Weight"]].copy()

# Ta bort rader som saknar kön, längd eller vikt.
# Varför: Vi kan inte beräkna medelvikt per längd om värden saknas.
data = data.dropna(subset=["Sex", "Height", "Weight"])

# Säkerställ att det endast är kön M/F (ifall datasetet innehåller annat).
data = data[data["Sex"].isin(["M", "F"])]

# Säkerställ numeriska kolumner (om CSV-läsning råkade ge strängar).
data["Height"] = pd.to_numeric(data["Height"], errors="coerce")
data["Weight"] = pd.to_numeric(data["Weight"], errors="coerce")
data = data.dropna(subset=["Height", "Weight"])  # rensa ev. ogiltiga konverteringar

# Avrunda längd till heltal i cm.
# Varför: Vi vill ha en diskret x-axel (1 cm-steg) för snygg linje.
data["Height_int"] = data["Height"].round().astype(int)

# ---------- 3) Aggregera: medelvikt per (Sex, Height_int) ----------
# Varför: Lineplot behöver ett y-värde per unikt x-värde.
grouped = (
    data.groupby(["Sex", "Height_int"])["Weight"]
        .mean()                                 # medelvikt för varje kombination
        .reset_index(name="MeanWeight")         # lägg resultatet i kolumn "MeanWeight"
)

# Gör om till brett format: en kolumn per kön, index = Height_int.
# Varför: Lättare att rita två linjer över samma x-axel.
pivot = grouped.pivot(index="Height_int", columns="Sex", values="MeanWeight")

# Sortera så att x-axeln (höjd) går stigande.
pivot = pivot.sort_index()

# ---------- 4) Rita lineplot ----------
# Viktigt: en (1) plott, ingen seaborn, inga manuella färger (enligt dina regler).
plt.figure(figsize=(10, 6))            # Skapa en figur (storlek i tum)
ax = plt.gca()                         # Hämta nuvarande axel

pivot.plot(ax=ax)                      # Rita två linjer: kolumnerna 'F' och 'M' mot index (Height_int)

# Etiketter och titel för läsbarhet (varför: tolka figuren i rapport).
ax.set_title("Mean Weight vs Height per Sex (line plot)")   # tydlig titel
ax.set_xlabel("Height (cm)")                                 # x-axelns etikett
ax.set_ylabel("Mean Weight (kg)")                            # y-axelns etikett

ax.grid(True)                                                # rutnät: lättare att avläsa
ax.legend(title="Sex")                                       # legend med rubrik

# ---------- 5) Spara och visa ----------
# Varför: Så att du kan länka figuren i din rapport eller lämna in.
out_dir = Path("/mnt/data/figures")
out_dir.mkdir(parents=True, exist_ok=True)                   # skapa mapp om den saknas
out_path = out_dir / "task_5_3_lineplot_weight_vs_height_per_sex.png"

plt.tight_layout()                                           # undvik att text klipps
plt.savefig(out_path, dpi=150)                               # spara PNG med ok upplösning
plt.show()                                                   # visa i notebook

print("✅ Figur sparad till:", out_path)
# Out:
# ✅ Figur sparad till: \mnt\data\figures\task_5_3_lineplot_weight_vs_height_per_sex.png

# %% [markdown]
# ---
# ## Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `scatterplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_4.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a scatter plot.

# %% [markdown]
# ---
# # Task 6: Map Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries
#
# Create a visualization showing the number of Medals awarded for the nordic countries (Sweden, Norway, Denmark, Finland).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_6_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the number of Medals on a Map for the nordic countries.

# %% [markdown]
# ---
# # Task 7: Submission
# ---

# %% [markdown]
# ## Task 7.1 Verify the Integrity of your Notebook

# %% [markdown]
# The final task is to verify your Notebook before submitting it, and of course submitting it via Canvas.
#
# - Have you included any additional packages you might have used in your Notebook under [Python Packages](#python-packages)?
# - Have you imported any additional modules you might have used in your Notebook under [Python Modules](#python-modules)?
# - Is your Pandas DataFrame (`df`) identical to the DataFrame `df_verify` under [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)?
# - Have you completed all tasks (`TODOs`) in the Notebook?
# - Have you reflected over your visualizations (semiology, expressiveness, effectiveness, etc.)?
#
# When you are done:
# - Click the `Restart` button at the top of the Notebook to restart the Jupyter Notebook kernel.
# - Then click the `Run All` button at the top of the Notebook, to execute all Notebook cells.
#   - Check that all Notebook cells executed successfully with the desired results.

# %% [markdown]
# ---
# ## Task 7.2 Submit the Assignment

# %% [markdown]
# - Save you Notebook and submit it via [Canvas](https://hb.instructure.com/courses/10009/assignments/40722) before the deadline (only submit one `.ipynb` file).
